# %%
import sys
import os
import pandas as pd

sys.path.append('../../get_data')
from get_data import GetData

# %%
pathToData = '../../tmp/data.csv'
if (os.path.exists(pathToData) == False):
  getData = GetData()
  getData.get_to_temp_folder('data.csv')

data = pd.read_csv(pathToData)
data
# Out:
#         Unnamed: 0      ID  year loan_limit             Gender approv_in_adv  \
# 0                0   24891  2019         cf               Male         nopre
# 1                1   24932  2019         cf               Male         nopre
# 2                2   25039  2019         cf               Male         nopre
# 3                3   25101  2019         cf               Male         nopre
# 4                4   25110  2019         cf               Male         nopre
# ...            ...     ...   ...        ...                ...           ...
# 148665      148665  164194  2019         cf  Sex Not Available         nopre
# 148666      148666  165831  2019         cf  Sex Not Available         nopre
# 148667      148667  100880  2019         cf  Sex Not Available         nopre
# 148668      148668  138588  2019         cf  Sex Not Available         nopre
# 148669      148669  157893  2019        ncf  Sex Not Available           pre
#
#        loan_type loan_purpose Credit_Worthiness open_credit  ... credit_type  \
# 0          type2           p1                l1        nopc  ...        EQUI
# 1          type3           p4                l1        nopc  ...        EQUI
# 2          type2           p3                l1        nopc  ...        EQUI
# 3          type1           p4                l1        nopc  ...        EQUI
# 4          type3           p3                l1        nopc  ...        EQUI
# ...          ...          ...               ...         ...  ...         ...
# 148665     type1           p4                l1        nopc  ...        CRIF
# 148666     type1           p3                l1        nopc  ...        CRIF
# 148667     type2           p3                l1        nopc  ...         CIB
# 148668     type3           p4                l1        nopc  ...         EXP
# 148669     type1           p1                l1        nopc  ...         EXP
#
#         Credit_Score  co_applicant_credit_type    age  \
# 0                552                       EXP  55-64
# 1                765                       EXP  45-54
# 2                880                       EXP  35-44
# 3                880                       EXP  45-54
# 4                768                       EXP  45-54
# ...              ...                       ...    ...
# 148665           851                       CIB  35-44
# 148666           645                       EXP  65-74
# 148667           525                       EXP  55-64
# 148668           798                       CIB  45-54
# 148669           836                       EXP  45-54
#
#         submission_of_application        LTV   Region Security_Type Status  \
# 0                         to_inst        NaN    North        direct      1
# 1                         to_inst        NaN    North        direct      1
# 2                         to_inst        NaN    North        direct      1
# 3                         to_inst        NaN  central        direct      1
# 4                        not_inst        NaN    North        direct      1
# ...                           ...        ...      ...           ...    ...
# 148665                    to_inst  57.593458    south        direct      0
# 148666                    to_inst  57.593458    south        direct      0
# 148667                    to_inst  92.725989    south        direct      1
# 148668                    to_inst  92.725989    south        direct      0
# 148669                    to_inst  64.950408    south        direct      1
#
#         dtir1
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 148665   45.0
# 148666   36.0
# 148667   44.0
# 148668    NaN
# 148669   43.0
#
# [148670 rows x 35 columns]
